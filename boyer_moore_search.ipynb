# %%
import timeit
import matplotlib.pyplot as plt

# Define array sizes for benchmarking
array_sizes = [100, 500, 1000, 2000, 5000]

# Boyer-Moore Algorithm
def boyer_moore_search(text, pattern):
    # Implementation of Boyer-Moore algorithm
    pass

def benchmark_boyer_moore(text, pattern, iterations):
    stmt = "boyer_moore_search(text, pattern)"
    setup = "from __main__ import boyer_moore_search, text, pattern"
    time_taken = timeit.timeit(stmt, setup, number=iterations)
    return time_taken / iterations

# Benchmarking Boyer-Moore for each array size
bm_times = []
for size in array_sizes:
    text = "A" * size
    pattern = "A" * (size // 10)
    bm_time = benchmark_boyer_moore(text, pattern, 100)
    bm_times.append(bm_time)

# Plotting Boyer-Moore
plt.plot(array_sizes, bm_times, marker='o', linestyle='-')
plt.xlabel('Array Size')
plt.ylabel('Time (seconds)')
plt.title('Performance of Boyer-Moore Algorithm')
plt.grid(True)
plt.show()
