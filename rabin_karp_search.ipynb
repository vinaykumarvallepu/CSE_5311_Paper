# %%
import timeit
import matplotlib.pyplot as plt

# Define array sizes for benchmarking
array_sizes = [100, 500, 1000, 2000, 5000]

# Rabin-Karp Algorithm
def rabin_karp_search(text, pattern):
    # Implementation of Rabin-Karp algorithm
    pass

def benchmark_rabin_karp(text, pattern, iterations):
    stmt = "rabin_karp_search(text, pattern)"
    setup = "from __main__ import rabin_karp_search, text, pattern"
    time_taken = timeit.timeit(stmt, setup, number=iterations)
    return time_taken / iterations

# Benchmarking Rabin-Karp for each array size
rk_times = []
for size in array_sizes:
    text = "A" * size
    pattern = "A" * (size // 10)
    rk_time = benchmark_rabin_karp(text, pattern, 100)
    rk_times.append(rk_time)

# Plotting Rabin-Karp
plt.plot(array_sizes, rk_times, marker='o', linestyle='-')
plt.xlabel('Array Size')
plt.ylabel('Time (seconds)')
plt.title('Performance of Rabin-Karp Algorithm')
plt.grid(True)
plt.show()
